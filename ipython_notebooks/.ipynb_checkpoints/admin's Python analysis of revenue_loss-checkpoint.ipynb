# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
dataset_revenue_loss = dataiku.Dataset("revenue_loss")

# %%
# Read the dataset as a Pandas dataframe
dataset_revenue_loss_df = dataset_revenue_loss.get_dataframe(limit=1000000)
pdu.audit(dataset_revenue_loss_df)
# Out:
#          _a_variable _b_data_type  _c_cardinality  _d_missings                    _e_sample_values
# 0              State       object              51            0                            [KS, OH]
# 1     Account_Length        int64             203            0                          [128, 107]
# 2          Area_Code        int64               3            0                          [415, 408]
# 3              Phone       object            1809            0                [382-4657, 371-7191]
# 4          Intl_Plan       object               2            0                           [no, yes]
# 5         VMail_Plan       object               2            0                           [yes, no]
# 6      VMail_Message        int64              41            0                            [25, 26]
# 7           Day_Mins      float64            1186            0                      [265.1, 161.6]
# ...

# %%
## Uncomment the following to read the dataset as a record stream
#dataset_revenue_loss_stream = dataset_revenue_loss.asStream()
#for record in dataset_revenue_loss.iter_rows():#    print record
